# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("synthetic_financial_data.csv",index_col=0)

# %%
df
# Out:
#                 customer_id  merchant_id   amount     transaction_time  \
# transaction_id
# 1                      1082         2027  5758.59  2023-01-01 00:00:00
# 2                      1015         2053  1901.56  2023-01-01 00:00:01
# 3                      1004         2035  1248.86  2023-01-01 00:00:02
# 4                      1095         2037  7619.05  2023-01-01 00:00:03
# 5                      1036         2083  1890.10  2023-01-01 00:00:04
# ...                     ...          ...      ...                  ...
# 9996                   1056         2023  8935.28  2023-01-01 02:46:35
# 9997                   1053         2026    30.15  2023-01-01 02:46:36
# 9998                   1041         2034  6333.64  2023-01-01 02:46:37
# 9999                   1009         2019  2837.13  2023-01-01 02:46:38
# 10000                  1082         2070  7209.43  2023-01-01 02:46:39
#
#                 is_fraudulent         card_type location purchase_category  \
# transaction_id
# ...

# %%
df.dtypes
# Out:
# customer_id                  int64
# merchant_id                  int64
# amount                     float64
# transaction_time            object
# is_fraudulent                int64
# card_type                   object
# location                    object
# purchase_category           object
# customer_age                 int64
# transaction_description     object
# dtype: object

# %%
df1=df.loc[:,["amount","is_fraudulent","customer_age"]]

# %%
df1
# Out:
#                  amount  is_fraudulent  customer_age
# transaction_id
# 1               5758.59              0            43
# 2               1901.56              1            61
# 3               1248.86              1            57
# 4               7619.05              1            59
# 5               1890.10              1            36
# ...                 ...            ...           ...
# 9996            8935.28              1            36
# 9997              30.15              0            42
# 9998            6333.64              0            36
# 9999            2837.13              1            57
# 10000           7209.43              1            50
#
# [10000 rows x 3 columns]

# %%
from sklearn import preprocessing

# %%
norm=preprocessing.normalize(df1)

# %%
norm
# Out:
# array([[9.99972122e-01, 0.00000000e+00, 7.46689750e-03],
#        [9.99485730e-01, 5.25613565e-04, 3.20624274e-02],
#        [9.98959726e-01, 7.99897287e-04, 4.55941454e-02],
#        ...,
#        [9.99983847e-01, 0.00000000e+00, 5.68384349e-03],
#        [9.99798180e-01, 3.52397733e-04, 2.00866708e-02],
#        [9.99975942e-01, 1.38703884e-04, 6.93519419e-03]])

# %%
out = pd.DataFrame(norm,columns=df1.columns)

# %%
out
# Out:
#         amount  is_fraudulent  customer_age
# 0     0.999972       0.000000      0.007467
# 1     0.999486       0.000526      0.032062
# 2     0.998960       0.000800      0.045594
# 3     0.999970       0.000131      0.007744
# 4     0.999819       0.000529      0.019043
# ...        ...            ...           ...
# 9995  0.999992       0.000112      0.004029
# 9996  0.583158       0.000000      0.812359
# 9997  0.999984       0.000000      0.005684
# 9998  0.999798       0.000352      0.020087
# 9999  0.999976       0.000139      0.006935
#
# [10000 rows x 3 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
scaled_data=scaler.fit_transform(df1)
scaled_data
# Out:
# array([[ 0.2759763 , -1.01369375, -0.06837047],
#        [-1.0542383 ,  0.98649123,  1.10649206],
#        [-1.27934184,  0.98649123,  0.8454115 ],
#        ...,
#        [ 0.47429986, -1.01369375, -0.52526146],
#        [-0.73157841,  0.98649123,  0.8454115 ],
#        [ 0.77634279,  0.98649123,  0.38852051]])

# %%
pd.DataFrame(scaled_data,columns=df1.columns)
# Out:
#         amount  is_fraudulent  customer_age
# 0     0.275976      -1.013694     -0.068370
# 1    -1.054238       0.986491      1.106492
# 2    -1.279342       0.986491      0.845411
# 3     0.917613       0.986491      0.975952
# 4    -1.058191       0.986491     -0.525261
# ...        ...            ...           ...
# 9995  1.371555       0.986491     -0.525261
# 9996 -1.699651      -1.013694     -0.133641
# 9997  0.474300      -1.013694     -0.525261
# 9998 -0.731578       0.986491      0.845411
# 9999  0.776343       0.986491      0.388521
#
# [10000 rows x 3 columns]

# %%
out
# Out:
#         amount  is_fraudulent  customer_age
# 0     0.999972       0.000000      0.007467
# 1     0.999486       0.000526      0.032062
# 2     0.998960       0.000800      0.045594
# 3     0.999970       0.000131      0.007744
# 4     0.999819       0.000529      0.019043
# ...        ...            ...           ...
# 9995  0.999992       0.000112      0.004029
# 9996  0.583158       0.000000      0.812359
# 9997  0.999984       0.000000      0.005684
# 9998  0.999798       0.000352      0.020087
# 9999  0.999976       0.000139      0.006935
#
# [10000 rows x 3 columns]

# %%
x=np.array([2,4,6,8,10])
y=np.array([3,6,9,12,15])
np.cov(x,y)[0,1]
#if x increases by 1 unit y increases 15 unit
# Out:
# 15.0

# %% [markdown]
# # CORRELATION

# %%
tips=pd.read_csv("tips.csv")

# %%
titanic=pd.read_csv("titanic.csv")

# %%
housing=pd.read_csv("housing.csv")

# %%
trends=pd.read_csv("shopping_trends.csv",index_col=0)

# %%
car=pd.read_csv("car_crashes.csv")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
cor_tips=tips.corr()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_5320\2352119920.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor_tips=tips.corr()

# %%
cor_tips
# tips and total bill is more related to the data and is showing +ve correlation which means when total bill increases tip also increase
#size is also related , but not much as total bill
#size is showing positive relation to total bill not in a big strength but still that indicates as size increases the tendency is a hike in the total bill also
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
cor_tips["tip"].sort_values(ascending=False)
# Out:
# tip           1.000000
# total_bill    0.675734
# size          0.489299
# Name: tip, dtype: float64

# %%
titanic
# Out:
#           pclass     sex   age  sibsp  parch     fare embarked   class    who  \
# survived
# 0              3    male  22.0      1      0   7.2500        S   Third    man
# 1              1  female  38.0      1      0  71.2833        C   First  woman
# 1              3  female  26.0      0      0   7.9250        S   Third  woman
# 1              1  female  35.0      1      0  53.1000        S   First  woman
# 0              3    male  35.0      0      0   8.0500        S   Third    man
# ...          ...     ...   ...    ...    ...      ...      ...     ...    ...
# 0              2    male  27.0      0      0  13.0000        S  Second    man
# 1              1  female  19.0      0      0  30.0000        S   First  woman
# 0              3  female   NaN      1      2  23.4500        S   Third  woman
# 1              1    male  26.0      0      0  30.0000        C   First    man
# 0              3    male  32.0      0      0   7.7500        Q   Third    man
#
# ...

# %%
cor_titanic=titanic.corr()
cor_titanic
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_5320\696265509.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor_titanic=titanic.corr()
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
# ...

# %%
cor_titanic["survived"].sort_values(ascending=False)
#fare is showing a very small +ve relation when the fare increase the class increase which result in the rescue faster
#showing negative relation towards male which indicates survival rate decreased in male which indicates there are chances male taking part in rescue operation risking their own lives
# Out:
# survived      1.000000
# fare          0.257307
# parch         0.081629
# sibsp        -0.035322
# age          -0.077221
# alone        -0.203367
# pclass       -0.338481
# adult_male   -0.557080
# Name: survived, dtype: float64

# %%
cor_titanic["pclass"].sort_values(ascending=False)
#pclass show negative correlation to fare becz if pclass increases its passenger class which means the fare will be less
# Out:
# pclass        1.000000
# alone         0.135207
# adult_male    0.094035
# sibsp         0.083081
# parch         0.018443
# survived     -0.338481
# age          -0.369226
# fare         -0.549500
# Name: pclass, dtype: float64

# %%
cor_titanic["age"].sort_values(ascending=False)
#sibsp and p class showing small negative relation
# Out:
# age           1.000000
# adult_male    0.280328
# alone         0.198270
# fare          0.096067
# survived     -0.077221
# parch        -0.189119
# sibsp        -0.308247
# pclass       -0.369226
# Name: age, dtype: float64

# %%
cor_titanic["sibsp"].sort_values(ascending=False)
#showing +ve relation to parch
#showing -ve relation to alone if the person is alone there is no chance for sibsp
# Out:
# sibsp         1.000000
# parch         0.414838
# fare          0.159651
# pclass        0.083081
# survived     -0.035322
# adult_male   -0.253586
# age          -0.308247
# alone        -0.584471
# Name: sibsp, dtype: float64

# %%
cor_titanic["parch"].sort_values(ascending=False)
#parch showing +ve relation to sibsp which means parent or children or family present
#showing -ve relation to alone , if the person is alone parent or children wont travel with them
# Out:
# parch         1.000000
# sibsp         0.414838
# fare          0.216225
# survived      0.081629
# pclass        0.018443
# age          -0.189119
# adult_male   -0.349943
# alone        -0.583398
# Name: parch, dtype: float64

# %%
cor_titanic["fare"].sort_values(ascending=False)
#refer above
# Out:
# fare          1.000000
# survived      0.257307
# parch         0.216225
# sibsp         0.159651
# age           0.096067
# adult_male   -0.182024
# alone        -0.271832
# pclass       -0.549500
# Name: fare, dtype: float64

# %%
cor_titanic["adult_male"].sort_values(ascending=False)
#refer above
# Out:
# adult_male    1.000000
# alone         0.404744
# age           0.280328
# pclass        0.094035
# fare         -0.182024
# sibsp        -0.253586
# parch        -0.349943
# survived     -0.557080
# Name: adult_male, dtype: float64

# %%
cor_titanic["alone"].sort_values(ascending=False)
#refer above
# Out:
# alone         1.000000
# adult_male    0.404744
# age           0.198270
# pclass        0.135207
# survived     -0.203367
# fare         -0.271832
# parch        -0.583398
# sibsp        -0.584471
# Name: alone, dtype: float64

# %%
car
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
car_cor=car.corr()
car_cor
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_5320\601503997.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   car_cor=car.corr()
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# ...

# %%
car_cor["total"].sort_values(ascending=False)
#no previous is showing maximum positive correlation
#alcohol is also showing positive correlation after no previous crashes(alcohol consumption increases shows increase in car crash also)
#not distracted is also showing positive corelation(even if the driver is not distracted opp people can be a reoson for car crash)
#speeding is showing positive corelation but the strength is less compared to the ones above(speed increase also result in increased car_crash) 
#ins losses ans ins premium is not showing much correlation
# Out:
# total             1.000000
# no_previous       0.956179
# alcohol           0.852613
# not_distracted    0.827560
# speeding          0.611548
# ins_losses       -0.036011
# ins_premium      -0.199702
# Name: total, dtype: float64

# %%
car_cor["no_previous"].sort_values(ascending=False)
#no previos is having high positive correlation with alcohol and not distracted
#which means even if there is no previous history of accident drunk and drive can cause car crashes
#no previous history is positive related to not distracted which means opp side accidents can happen
# Out:
# no_previous       1.000000
# total             0.956179
# alcohol           0.783520
# not_distracted    0.747307
# speeding          0.571976
# ins_losses       -0.006359
# ins_premium      -0.156895
# Name: no_previous, dtype: float64

# %%
car_cor["alcohol"].sort_values(ascending=False)
# Out:
# alcohol           1.000000
# total             0.852613
# no_previous       0.783520
# not_distracted    0.732816
# speeding          0.669719
# ins_losses       -0.112547
# ins_premium      -0.170612
# Name: alcohol, dtype: float64

# %%
car_cor["not_distracted"].sort_values(ascending=False)
#no distraction is having high correlation with total
# Out:
# not_distracted    1.000000
# total             0.827560
# no_previous       0.747307
# alcohol           0.732816
# speeding          0.588010
# ins_losses       -0.075970
# ins_premium      -0.174856
# Name: not_distracted, dtype: float64

# %%
car_cor["speeding"].sort_values(ascending=False)
#speeding and alcohol showing +ve relation which means high alcohol results in high speed
# Out:
# speeding          1.000000
# alcohol           0.669719
# total             0.611548
# not_distracted    0.588010
# no_previous       0.571976
# ins_losses       -0.065928
# ins_premium      -0.077675
# Name: speeding, dtype: float64

# %%
trends
# Out:
#              Age  Gender Item Purchased     Category  Purchase Amount (USD)  \
# Customer ID
# 1             55    Male         Blouse     Clothing                     53
# 2             19    Male        Sweater     Clothing                     64
# 3             50    Male          Jeans     Clothing                     73
# 4             21    Male        Sandals     Footwear                     90
# 5             45    Male         Blouse     Clothing                     49
# ...          ...     ...            ...          ...                    ...
# 3896          40  Female         Hoodie     Clothing                     28
# 3897          52  Female       Backpack  Accessories                     49
# 3898          46  Female           Belt  Accessories                     33
# 3899          44  Female          Shoes     Footwear                     77
# 3900          52  Female        Handbag  Accessories                     81
#
# ...

# %%
trends_corr=trends.corr()
trends_corr
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_5320\742139079.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   trends_corr=trends.corr()
#                             Age  Purchase Amount (USD)  Review Rating  \
# Age                    1.000000              -0.010424      -0.021949
# Purchase Amount (USD) -0.010424               1.000000       0.030776
# Review Rating         -0.021949               0.030776       1.000000
# Previous Purchases     0.040445               0.008063       0.004229
#
#                        Previous Purchases
# Age                              0.040445
# Purchase Amount (USD)            0.008063
# Review Rating                    0.004229
# Previous Purchases               1.000000

# %%
trends_corr["Age"].sort_values(ascending=False)
#none of the points are showing correlation as the values are more close to 0
# Out:
# Age                      1.000000
# Previous Purchases       0.040445
# Purchase Amount (USD)   -0.010424
# Review Rating           -0.021949
# Name: Age, dtype: float64

# %%
trends_corr["Previous Purchases"].sort_values(ascending=False)
# Out:
# Previous Purchases       1.000000
# Age                      0.040445
# Purchase Amount (USD)    0.008063
# Review Rating            0.004229
# Name: Previous Purchases, dtype: float64

# %%
trends_corr["Purchase Amount (USD)"].sort_values(ascending=False)
# Out:
# Purchase Amount (USD)    1.000000
# Review Rating            0.030776
# Previous Purchases       0.008063
# Age                     -0.010424
# Name: Purchase Amount (USD), dtype: float64

# %%
housing
# Out:
#            latitude  housing_median_age  total_rooms  total_bedrooms  \
# longitude
# -122.23       37.88                41.0        880.0           129.0
# -122.22       37.86                21.0       7099.0          1106.0
# -122.24       37.85                52.0       1467.0           190.0
# -122.25       37.85                52.0       1274.0           235.0
# -122.25       37.85                52.0       1627.0           280.0
# ...             ...                 ...          ...             ...
# -121.09       39.48                25.0       1665.0           374.0
# -121.21       39.49                18.0        697.0           150.0
# -121.22       39.43                17.0       2254.0           485.0
# -121.32       39.43                18.0       1860.0           409.0
# -121.24       39.37                16.0       2785.0           616.0
#
#            population  households  median_income  median_house_value  \
# longitude
# ...

# %%
housing_corr=housing.corr()
housing_corr
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_5320\1346480756.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   housing_corr=housing.corr()
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# ...

# %%
housing_corr["longitude"].sort_values(ascending=False)
#longitude is showing high negative correlation with latitude which means when latitude increases longitude decreases and vice versa
# Out:
# longitude             1.000000
# population            0.099773
# total_bedrooms        0.069608
# households            0.055310
# total_rooms           0.044568
# median_income        -0.015176
# median_house_value   -0.045967
# housing_median_age   -0.108197
# latitude             -0.924664
# Name: longitude, dtype: float64

# %%
housing_corr["latitude"].sort_values(ascending=False)
#showing big-ve relation to longitude
# Out:
# latitude              1.000000
# housing_median_age    0.011173
# total_rooms          -0.036100
# total_bedrooms       -0.066983
# households           -0.071035
# median_income        -0.079809
# population           -0.108785
# median_house_value   -0.144160
# longitude            -0.924664
# Name: latitude, dtype: float64

# %%
housing_corr["population"].sort_values(ascending=False)
#population is showing big +ve relation to house holds as population increases demands for household also increase
#population and total bedroom and rooms also show +ve correlation as the number of heads increases room supply will also increase
#housing median age is showing very small negative deviation to population which means when age increases population decreases but the magnitude is small which shows the decreased strength of the correlation
# Out:
# population            1.000000
# households            0.907222
# total_bedrooms        0.877747
# total_rooms           0.857126
# longitude             0.099773
# median_income         0.004834
# median_house_value   -0.024650
# latitude             -0.108785
# housing_median_age   -0.296244
# Name: population, dtype: float64

# %%
housing_corr["total_bedrooms"].sort_values(ascending=False)
#total bedroom showing high +ve correlation to total rooms and house holds as total bedroom increases the house hold needs as well as the number of rooms increases
#population is also showing +ve relation becz population increase demands an increase in bedroom number also
#a small negative correlation towards housing median age as age increases number of bedroom decrease
# Out:
# total_bedrooms        1.000000
# households            0.979728
# total_rooms           0.930380
# population            0.877747
# longitude             0.069608
# median_house_value    0.049686
# median_income        -0.007723
# latitude             -0.066983
# housing_median_age   -0.320451
# Name: total_bedrooms, dtype: float64

# %%
housing_corr["housing_median_age"].sort_values(ascending=False)
#less correlation is observed to either side but a smal -ve deviation towards total rooms and bedrooms
# Out:
# housing_median_age    1.000000
# median_house_value    0.105623
# latitude              0.011173
# longitude            -0.108197
# median_income        -0.119034
# population           -0.296244
# households           -0.302916
# total_bedrooms       -0.320451
# total_rooms          -0.361262
# Name: housing_median_age, dtype: float64

# %%
housing_corr["total_rooms"].sort_values(ascending=False)
# Out:
# total_rooms           1.000000
# total_bedrooms        0.930380
# households            0.918484
# population            0.857126
# median_income         0.198050
# median_house_value    0.134153
# longitude             0.044568
# latitude             -0.036100
# housing_median_age   -0.361262
# Name: total_rooms, dtype: float64

# %%
housing_corr["households"].sort_values(ascending=False)
#showing high +ve relation to total rooms bedrooms and population the detailings and given above
# Out:
# households            1.000000
# total_bedrooms        0.979728
# total_rooms           0.918484
# population            0.907222
# median_house_value    0.065843
# longitude             0.055310
# median_income         0.013033
# latitude             -0.071035
# housing_median_age   -0.302916
# Name: households, dtype: float64

# %%
housing_corr["median_house_value"].sort_values(ascending=False)
#showing +ve relation to income which shows the income increase result in the increased house value also
# Out:
# median_house_value    1.000000
# median_income         0.688075
# total_rooms           0.134153
# housing_median_age    0.105623
# households            0.065843
# total_bedrooms        0.049686
# population           -0.024650
# longitude            -0.045967
# latitude             -0.144160
# Name: median_house_value, dtype: float64

# %%
housing_corr["median_income"].sort_values(ascending=False)
# Out:
# median_income         1.000000
# median_house_value    0.688075
# total_rooms           0.198050
# households            0.013033
# population            0.004834
# total_bedrooms       -0.007723
# longitude            -0.015176
# latitude             -0.079809
# housing_median_age   -0.119034
# Name: median_income, dtype: float64

# %%
taxis=pd.read_csv("taxis.csv")
taxis
# Out:
#                    pickup              dropoff  passengers  distance  fare  \
# 0     2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0
# 1     2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0
# 2     2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5
# 3     2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.0
# 4     2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16   9.0
# ...                   ...                  ...         ...       ...   ...
# 6428  2019-03-31 09:51:53  2019-03-31 09:55:27           1      0.75   4.5
# 6429  2019-03-31 17:38:00  2019-03-31 18:34:23           1     18.74  58.0
# 6430  2019-03-23 22:55:18  2019-03-23 23:14:25           1      4.14  16.0
# 6431  2019-03-04 10:09:25  2019-03-04 10:14:29           1      1.12   6.0
# 6432  2019-03-13 19:31:22  2019-03-13 19:48:02           1      3.85  15.0
#
# ...

# %%
taxi_cor=taxis.corr()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_5320\1807905749.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   taxi_cor=taxis.corr()

# %%
taxi_cor
#distance show high +ve correlation with the fare and total bill becz as distance increases the fare also increase,in context to this tip and tolls are also showing positive relation which tells us the distance increase result in payment of tolls and tips
#fare show +ve relation with distance and total
# Out:
#             passengers  distance      fare       tip     tolls     total
# passengers    1.000000  0.009411  0.007637  0.021099 -0.002903  0.015708
# distance      0.009411  1.000000  0.920108  0.452589  0.635267  0.904676
# fare          0.007637  0.920108  1.000000  0.488612  0.609307  0.974358
# tip           0.021099  0.452589  0.488612  1.000000  0.413619  0.646186
# tolls        -0.002903  0.635267  0.609307  0.413619  1.000000  0.683142
# total         0.015708  0.904676  0.974358  0.646186  0.683142  1.000000

# %%
weather=pd.read_csv("GlobalWeatherRepository.csv")

# %%
weather
# Out:
#           country     location_name  latitude  longitude         timezone  \
# 0     Afghanistan             Kabul     34.52      69.18       Asia/Kabul
# 1         Albania            Tirana     41.33      19.82    Europe/Tirane
# 2         Algeria           Algiers     36.76       3.05   Africa/Algiers
# 3         Andorra  Andorra La Vella     42.50       1.52   Europe/Andorra
# 4          Angola            Luanda     -8.84      13.23    Africa/Luanda
# ...           ...               ...       ...        ...              ...
# 9541    Venezuela           Caracas     10.50     -66.92  America/Caracas
# 9542      Vietnam             Hanoi     21.03     105.85     Asia/Bangkok
# 9543        Yemen             Sanaa     15.35      44.21        Asia/Aden
# 9544       Zambia            Lusaka    -15.42      28.28    Africa/Lusaka
# 9545     Zimbabwe            Harare    -17.82      31.04    Africa/Harare
#
#       last_updated_epoch      last_updated  temperature_celsius  \
# ...

# %%
weather.corr()
#temp cel shows high +ve relation to temp farenheit feels like celcius , and feels like farenheit , becz if one scale increases other also incraeases
#temp cel shows small -ve relation to pressure which indicates if temp increases pressure decreses not in a high amount but it tends to
#moon illumination is not showing any relation to either factors
#sulphur dioxide showing +ve correlation to nitrogen dioxide
#air quality showing +ve relation with carbon dioxide
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_5320\2459116109.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   weather.corr()
#                               latitude  longitude  last_updated_epoch  \
# latitude                      1.000000  -0.013652           -0.000265
# longitude                    -0.013652   1.000000            0.000785
# last_updated_epoch           -0.000265   0.000785            1.000000
# temperature_celsius          -0.343188  -0.152681           -0.072088
# temperature_fahrenheit       -0.343211  -0.152685           -0.072083
# wind_mph                     -0.089537  -0.125799            0.022586
# wind_kph                     -0.089568  -0.125923            0.022797
# wind_degree                   0.104342   0.002040            0.020470
# ...
